# %%
a=5
b=4.09
c="hello"
d='s'

# %%
print("type of the variable a is ",type(a))
print("type of the variable b is ",type(b))
print("type of the variable c is ",type(c))
print("type of the variable d is ",type(d))
# Out:
# type of the variable a is  <class 'int'>
# type of the variable b is  <class 'float'>
# type of the variable c is  <class 'str'>
# type of the variable d is  <class 'str'>

# %% [markdown]
# # List
# #### - same as array
# #### - it can store multiple types of data
# #### - indexing starts with "0"
# #### - the elements can be edited how ever we like
# ### syntax
# #### -variable_name=[ele1,ele2,........]

# %%
my_list=[1,"vishnu",2,3.5]
print("Before editing:",my_list)
my_list[2]

my_list[3]="study hard"
print("After editing the third elemnt",my_list)
# Out:
# before editing: [1, 'vishnu', 2, 3.5]
# after editing the third elemnt [1, 'vishnu', 2, 'study hard']

# %% [markdown]
# # Tuples
# #### - are used to strore multiple items in a single variable
# #### - once tuples are made unlike list the elements cannot be changed
# ### Syntax
# #### my_tuple=( ele1,ele2........)

# %%
my_tuple = (1,2.0,"hello")
print(my_tuple)
# Out:
# (1, 2.0, 'hello')

# %% [markdown]
# #### >>trying to edit a tuple will lead to error

# %%
my_tuple[0]="one"
print("edited tuple :",my_tuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 my_tuple[0]="one"
#       2 print("edited tuple :",my_tuple)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# #### - in PYTHON "( )" are generally used for 'function call' and defining 'tuple'
# #### - '[ ]" are used for lists adn indexing elements in both list and tuples

# %% [markdown]
# # Range( )
# #### -it is used to write a sequence of vakues in range
# ## Syntax
# #### range( start , stop , step)

# %%
r=range(1,10,2)
a=list(r)
b=tuple(r)
print("list: ",a)
print("tuple:",b)
# Out:
# list:  [1, 3, 5, 7, 9]
# tuple: (1, 3, 5, 7, 9)

# %% [markdown]
# # Mapping
# #### Mapping can be divide into 2
# ####       1)sets
# ####       2)Dictionaries

# %% [markdown]
# # SETS
# #### -sets are unodered ,mutable collection of elements
# ## Syntax
# #### - set_variable_name={ele1, ele2 ,ele3...............}
# #### -set can be converted in to list ,tuples and vice versa
# #### -indexing in set is not allowed

# %%
variable={1,"abc",2.0,222}
print("set:",variable)
# Out:
# set: {'abc', 1, 2.0, 222}

# %% [markdown]
# # Dictionary
# #### - its  a key-value pair
# #### -defined using curly braces with key saperated by value using coloumn
# ## syntax
# ### my_dictionary={key1 : value1 ,key2 : value2.........}
# #### key value can be any thing int,char,float....

# %%
my_dict={"hello":"hi","phone":96003736736, 1:"one","two":2.0}
my_dict
# Out:
# {'hello': 'hi', 'phone': 96003736736, 1: 'one', 'two': 2.0}

# %%
x = my_dict["hello"]
y=my_dict["phone"]
z=my_dict[1]
w=my_dict["two"]
print("value of key 'hello' is: " ,x)
print("value of key 'phone is: " ,y)
print("value of key '1' is: " ,z)
print("value of key 'two' is: " ,w)
# Out:
# value of key 'hello' is:  hi
# value of key 'phone is:  96003736736
# value of key '1' is:  one
# value of key 'two' is:  2.0
