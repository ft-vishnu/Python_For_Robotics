# %% [markdown]
# ### Print() Statement
# #### what is print()
#     - A print() statement in Python is used to display/output information on the screen.
# #### Syntax:-
#     print("<content>")

# %%
print("hello welcome to robotics")
# Out:
# hello welcome to robotics

# %% [markdown]
# ###  we can also print a symbol n times in a row using print
# #### syntax:-
# - print("anything"*n)
# - where 'n' is the no of times symbol has to be printed

# %%
print("hello-"*5)
print("+"*5)
# Out:
# hello-hello-hello-hello-hello-
# +++++

# %% [markdown]
# ### Using Plus(+) in print
# - plus('+') is generally used for concatination ie. to connect a string with another<br>
# - we cannot concat a string and any other data type this will lead to error<br>
# - Used to add numbers or join strings.
# ### NOTE:-
#
# - `print(a+c)` will lead to an error since:
#   - `type(a)` = string
#   - `type(c)` = int

# %%
a='hello'
b='world'
c=123
print(a + b)
# Out:
# helloworld

# %% [markdown]
# ###  Using comma( , ) in print
#   - comma(',') is used when we have to join multiple datatypes such as string and a numetric datatypes

# %%
x="hello"
y="student_id"
pno=1234567891
print(a,",arun your new",b,"is :",pno)
